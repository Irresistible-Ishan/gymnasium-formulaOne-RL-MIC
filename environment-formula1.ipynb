# %% [markdown]
# This is the environment , enjoy , dont no edit the blocks marked as red , only edit and alter the yellow blocks

# %%
# Cell 1: Install and configure environment
# !pip install pygame gymnasium stable-baselines3 imageio[ffmpeg] pandas tabulate -q

import os
# Force Pygame to run headlessly in Google Colab without needing an X11 window
os.environ["SDL_VIDEODRIVER"] = "dummy"
print("Dependencies installed and headless display configured successfully!")
